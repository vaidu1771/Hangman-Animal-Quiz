# %% [markdown]
# #**Hangman Animal Quiz**
# - 18DIT035 Mijoli Mehta
# - 18DIT035 Vaidehi Patel

# %%
import random

hangman_pics = ['''
    +---+
         |
         |
         |
        ===''', '''
    +---+
    O   |
        |
        |
       ===''', '''
    +---+
    O   |
    |   |
        |
       ===''', '''
    +---+
    O   |
   /|   |
        |
       ===''', '''
    +---+
    O   |
   /|\  |
        |
       ===''', '''
    +---+
    O   |
   /|\  |
   /    |
       ===''', '''
    +---+
    O   |
   /|\  |
   / \  |
       ===''']
       
words = 'ant anteater antelop baboon bat bear camel cat cobra cougar coyote crow deer dog donkey duck eagle elephant fox frog goat goose horse iguana jaguar kangaroo kingfisher kiwi lion lizard llama mole monkey moose mouse mule nute nightingle owl ostrich panda parrot pigeon python quail rabbit rat rhino seal shark sheep snake spider stork swan tiger turkey turtle ukari vampirebat vulture whale wolf wombat yak zebra'.split()

def getRandomWord(wordList):
    wordIndex = random.randint(0, len(wordList) - 1)
    return wordList[wordIndex]

def displayBoard(missedLetters, correctLetters, secretWord):
    print()
    print(hangman_pics[len(missedLetters)])

    print()
    print('Missed letters: ', end=' ')
    for letter in missedLetters:
        print(letter, end=' ')

    print()
    blanks = '_' * len(secretWord)
    for i in range(len(secretWord)):
        if secretWord[i] in correctLetters:
            blanks = blanks[:i] + secretWord[i] + blanks[i+1:]
   
    for letter in blanks:
        print(letter, end =' ')
    print()

def getGuess(alreadyGuessed):
    while True:
        print('Please guess a letter.')
        guess = input()
        guess = guess.lower()
        if len(guess) != 1:
            print('Only a single letter is allowed.')
        elif guess in alreadyGuessed:
            print('You have already guessed that letter. Choose again.')
        elif guess not in 'abcdefghijklmnopqrstuvwxyz':
            print('Please enter a letter from the alphabet.')
        else:
            return guess

def playAgain():
    print('Would you like to play again? (y)es or (n)o')
    return input().lower().startswith('y')

print('|_H_A_N_G_M_A_N_|')
missedLetters = ''
correctLetters = ''
secretWord = getRandomWord(words)
gameIsDone = False

while True:
    displayBoard(missedLetters, correctLetters, secretWord)
    guess = getGuess(missedLetters + correctLetters)

    if guess in secretWord:
        correctLetters = correctLetters + guess
        foundAllLetters = True
        for i in range(len(secretWord)):
            if secretWord[i] not in correctLetters:
                foundAllLetters = False
                break
        if foundAllLetters:
            print('You guessed it!')
            print('The secret word is "' + secretWord + '"! You win!')
            gameIsDone = True
    else:
        missedLetters = missedLetters + guess
        if len(missedLetters) == len(HANGMAN_PICS) -1:
            displayBoard(missedLetters, correctLetters, secretWord)
            print('You have run out of guesses!\nAfter ' + str(len(missedLetters)) + ' missed guesses and ' + str(len(correctLetters)) + ' correct guesses, the word was "' + secretWord + '"')
            gameIsDone = True
  
    if gameIsDone:
        if playAgain():
            missedLetters = ''
            correctLetters = ''
            gameIsDone = False
            secretWord = getRandomWord(words)
        else:
            break
# Out:
# |_H_A_N_G_M_A_N_|
#
#
#     +---+
#          |
#          |
#          |
#         ===
#
# Missed letters:
# _ _ _ _
# Please guess a letter.
# e
#
#
#     +---+
#     O   |
#         |
#         |
#        ===
#
# Missed letters:  e
# _ _ _ _
# Please guess a letter.
# o
#
#
#     +---+
#     O   |
#     |   |
#         |
#        ===
#
# Missed letters:  e o
# _ _ _ _
# Please guess a letter.
# a
#
#
#     +---+
#     O   |
#    /|   |
#         |
#        ===
#
# Missed letters:  e o a
# _ _ _ _
# Please guess a letter.
# i
#
#
#     +---+
#     O   |
#    /|\  |
#         |
#        ===
#
# Missed letters:  e o a i
# _ _ _ _
# Please guess a letter.
# q
#
#
#     +---+
#     O   |
#    /|\  |
#    /    |
#        ===
#
# Missed letters:  e o a i q
# _ _ _ _
# Please guess a letter.
# u
#
#
#     +---+
#     O   |
#    /|\  |
#    /    |
#        ===
#
# Missed letters:  e o a i q
# _ u _ _
# Please guess a letter.
# k
#
#
#     +---+
#     O   |
#    /|\  |
#    /    |
# ...
